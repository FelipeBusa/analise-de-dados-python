# %% [markdown]
# ## Exercício 1 - Vendas por Produto (Nível Médio):
# Uma loja registrou as seguintes vendas abaixo. Mostre o valor de cada produto individual e quantos produtos venderam mais de 10 unidades.

# %%
produtos = ["Notebook", "Mouse", "Teclado", "Monitor"]
quantidades = [8, 25, 12, 5]

# %% [markdown]
# ## Exercício 2 - Cadastro de Funcionário (Nível Médio):
# Crie um dicionário para armazenar:
# * Nome
# * Cargo
# * Salário
# * Tempo de empresa
#
# Mostre todas as informações utilizando f-strings.
#
# Depois faça:
# * Se salário for maior que 5000 "Salário acima da média." Caso contrário "Salário dentro da média."

# %%
funcionario = {
    "nome": "Carlos",
    "cargo": "Analista",
    "salario": 4800,
    "anos_empresa": 4
}

# %% [markdown]
# ## Exercício 3 - Controle de Estoque (Nível Médio):
#
# Uma empresa possui um estoque com vários produto. Crie uma lista com dicionário para cada produto e valor.
# Percorra o dicionário para cada produto: Se a quantidade <3 'Reposição urgente' caso contrário 'Estoque OK'

# %%
estoque = {
    "Notebook": 18,
    "Mouse": 4,
    "Monitor": 7,
    "Teclado": 25
}

# %% [markdown]
# ____________
# ## Exercício 4 — Análise Comercial (Nível Difícil)
# As vendas do mês foram: vendas = [1250, 980, 2300, 450, 1750, 890, 3200]. Percorra a lista e informe:
# * Quantas vendas foram maiores que R$1000
# * Quantas vendas foram menores que R$1000
# * Quantas vendas são valores pares (utilize %)
# Ao final mostre o total de cada categoria.

# %% [markdown]
# ## Exercício 5 — Ranking de Lojas (Nível Difícil)
# Uma empresa possui um dicionário. Percorra a lista. Para cada loja:
# * Se faturamento maior que R$100.000 "Meta atingida"
# * Caso contrário "Meta não atingida"

# %%
lojas = [
    {"nome": "Joinville", "faturamento": 85000},
    {"nome": "Curitiba", "faturamento": 112000},
    {"nome": "Blumenau", "faturamento": 76000},
    {"nome": "Florianópolis", "faturamento": 135000}
]

# %% [markdown]
# ## Exercício 6 — Auditoria de Clientes (Nível Difícil)
# Você recebeu. Cada tupla representa: (nome, quantidade de compras).
#
# Mostre: Felipe realizou 5 compras.
#
# Depois classifique:
# * 0 compras - Cliente Inativo
# * 1 até 3 - Cliente Ativo
# * Acima de 3 - Cliente VIP

# %%
clientes = [
    ("Felipe", 5),
    ("Ana", 1),
    ("João", 0),
    ("Carlos", 3),
    ("Maria", 8)
]

# %% [markdown]
# ______________
# ## Exercício 7 — Dashboard Comercial (Desafiador)
# Você recebeu a seguinte base: Percorra a lista e informe:
# * Quantas vendas cada vendedor realizou.
# * Quantas vendas foram maiores que R$1500.
# * Quantas vendas foram menores ou iguais a R$1500.

# %%
vendas = [
    {"vendedor":"Ana","valor":1200},
    {"vendedor":"Ana","valor":800},
    {"vendedor":"Carlos","valor":2100},
    {"vendedor":"Maria","valor":950},
    {"vendedor":"Carlos","valor":1800},
    {"vendedor":"Maria","valor":1500}
]

# %% [markdown]
# ## Exercício 8 — Controle de Chamados de TI (Desafiador)
# Uma empresa possui: Percorra o dicionário. Para cada situação:
# * Se quantidade maior que 10 - Alta demanda
# * Caso contrário - Fluxo normal
#
# Depois informe quantos chamados ainda não foram resolvidos. (Considere "Aberto" e "Em andamento" como não resolvidos.)

# %%
chamados = {
    "Aberto": 14,
    "Em andamento": 7,
    "Resolvido": 31,
    "Cancelado": 2
}

# %% [markdown]
# ## Exercício 9 — Controle Financeiro (Desafiador)
# Uma empresa registrou as movimentações: Percorra a lista. Mostre cada movimentação. No final informe:
# * Quantidade de receitas.
# * Quantidade de despesas.
# * Valor total das receitas.
# * Valor total das despesas.
# * Se o total de receitas for maior que o total de despesas: Empresa teve lucro.
# * Caso contrário: Empresa teve prejuízo.

# %%
movimentacoes = [
    ("Receita", 2500),
    ("Despesa", 1200),
    ("Receita", 4200),
    ("Despesa", 950),
    ("Receita", 3100),
    ("Despesa", 700)
]

# %% [markdown]
# ## Exercício 10 — Mini Projeto de Análise de Dados (Desafiador)
# Você recebeu uma base simplificada de vendas: Sem utilizar funções prontas como sum() ou max(), percorra a lista e descubra:
# * Quantas vendas existem.
# * Quantos produtos pertencem à categoria Informática.
# * Quantos pertencem à categoria Móveis.
# * Quantas vendas foram acima de R$1.000.
# * Quantas vendas foram abaixo ou iguais a R$1.000.
# * Valor total vendido (utilizando um acumulador).
# * Informe se a empresa bateu a meta: Meta atingida: faturamento acima de R$10.000.
# * Meta não atingida: caso contrário.

# %%
vendas = [
    {"produto":"Notebook","categoria":"Informática","valor":4200},
    {"produto":"Mouse","categoria":"Informática","valor":80},
    {"produto":"Mesa","categoria":"Móveis","valor":950},
    {"produto":"Monitor","categoria":"Informática","valor":1400},
    {"produto":"Cadeira","categoria":"Móveis","valor":780},
    {"produto":"Notebook","categoria":"Informática","valor":3900}
]

# %% [markdown]
# ## 💡 Desafio Extra (Opcional)
# Imagine que você está participando de um processo seletivo para Analista de Dados. Escolha um dos exercícios acima e tente deixá-lo mais profissional, por exemplo:
#
# * Organizando melhor a saída com f-strings.
# * Criando títulos e separadores no terminal (print("=" * 40)).
# * Nomeando variáveis de forma clara.
# * Adicionando comentários explicando a lógica.
#
# Esses detalhes demonstram organização e boas práticas, características valorizadas em entrevistas técnicas e no dia a dia de quem trabalha com análise de dados.
#
# Quando terminar cada exercício, envie seu código. Em vez de apenas dizer se está certo ou errado, vou fazer uma revisão como se fosse um Tech Lead, apontando melhorias de lógica, legibilidade, boas práticas e formas mais "Pythonicas" de escrever o código. Isso vai acelerar bastante sua evolução.
